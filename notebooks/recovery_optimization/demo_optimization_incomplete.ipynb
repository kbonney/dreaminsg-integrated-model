# %%
#Go to the main directory
#!pip install --editable .
#!pip install pandas
# !pip install wntr
# !pip install pandapower
# !pip install sklearn

#to find requirements
#depfinder -y .

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Import required packages

# %%
from pathlib import Path
from infrarisk.src.network_recovery import *
import infrarisk.src.simulation as simulation
from infrarisk.src.physical.integrated_network import *

from infrarisk.src.physical.interdependencies import *

from infrarisk.src.optimizer import *
import infrarisk.src.plots as model_plots

# %% [markdown]
# ## Create an IntegratedNetwork object

# %%
simple_network = IntegratedNetwork(name = "Simple")

# %% [markdown]
# ### Load the three infrastructure models: Water, Power and Transportation
#
# Three different models are used:
# - Water distribution network using **wntr** package
# - Power systems using **pandapower** package
# - Transportation network using static traffic assignment package developed by Dr. Stephen Boyles (University of Texas at Austin)

# %%
MAIN_DIR = Path('../..')

network_dir= 'infrarisk/data/networks/in2'
water_folder = MAIN_DIR/f'{network_dir}/water'
power_folder = MAIN_DIR/f'{network_dir}/power'
transp_folder = MAIN_DIR/f'{network_dir}/transportation/'

# load all infrastructure networks
simple_network.load_networks(water_folder, 
                             power_folder, 
                             transp_folder, '1ph',
                             water_sim_type = "PDA")
# Out:
# Water network successfully loaded from ../../infrarisk/data/networks/in2/water/water.inp. The analysis type is set to PDA.
# initial simulation duration: 60s; hydraulic time step: 60s; pattern time step: 3600s
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
# Power system successfully loaded from ../../infrarisk/data/networks/in2/power/power.json. Single phase power flow simulation will be used.
#
# Transportation network successfully loaded from ../../infrarisk/data/networks/in2/transportation. Static traffic assignment method will be used to calculate travel times.

# %% [markdown]
# ### Create a Networkx graph of the integrated infrastructure network.

# %%
simple_network.generate_integrated_graph()
# Out:
# Successfully added power network to the integrated graph...
# Successfully added water network to the integrated graph...
# Successfully added transportation network to the integrated graph...
# Integrated graph successfully created.
# Generating betweenness centrality...
# /home/klbonne/repos/dreaminsg-integrated-model/infrarisk/src/physical/integrated_network.py:335: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   power_nodes = pd.concat([power_nodes, pd.DataFrame([{
# /home/klbonne/repos/dreaminsg-integrated-model/infrarisk/src/physical/integrated_network.py:427: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   water_nodes = pd.concat([water_nodes, pd.DataFrame([{
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d8472c97-2d92-4dd0-99bb-acf87f4c2a53">Loading BokehJS ...</span>
#     </div>
# BokehDeprecationWarning: 'square() method' was deprecated in Bokeh 3.4.0 and will be removed, use "scatter(marker='square', ...) instead" instead.
#   <div id="ea5a61c6-6171-4182-a573-ce7e7884c398" data-root-id="p1003" style="display: contents;"></div>
# figure(id='p1003', ...)

# %% [markdown]
# ### Build interdependencies
#
# Three types of dependencies:
# - Power - Water dependencies (eg.: water pump on electric motor, generator on reservoir)
# - Power - Transportation dependencies (eg.: road access to power system components for M&R)
# - Water - Transportation dependencies (eg.: road access to water network components for M&R)
#
# The dependencies are referenced using two tables in the model.
# - **wp_table** for water - power dependencies
# - **access_table** for transportation dependencies

# %%
dependency_file = MAIN_DIR/f"{network_dir}/dependecies.csv"
simple_network.generate_dependency_table(dependency_file = dependency_file)
simple_network.dependency_table.wp_table
# Out:
# /home/klbonne/repos/dreaminsg-integrated-model/infrarisk/src/physical/interdependencies.py:167: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.access_table = pd.concat([self.access_table, new_row], ignore_index=True)
#   water_id power_id water_type power_type
# 0    W_WP9    P_MP1       Pump      Motor
# 1     W_R9     P_G3  Reservoir  Generator

# %%
simple_network.dependency_table.access_table.head()
# Out:
#   origin_id transp_id origin_cat origin_type  access_dist
# 0      P_B1      T_J7      power         Bus        111.8
# 1      P_B2      T_J7      power         Bus        111.8
# 2      P_B3      T_J7      power         Bus        100.0
# 3      P_B4      T_J7      power         Bus         50.0
# 4      P_B5      T_J7      power         Bus        100.0

# %% [markdown]
# ### Set failed components

# %%
scenario_folder = "scenarios/test1"
scenario_file = MAIN_DIR/f"{network_dir}/{scenario_folder}/disruption_file.csv"

simple_network.set_disrupted_components(disruption_file=scenario_file)
simple_network.get_disrupted_components()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 scenario_folder = "scenarios/test1"
#       2 scenario_file = MAIN_DIR/f"{network_dir}/{scenario_folder}/disruption_file.csv"
# ----> 4 simple_network.set_disrupted_components(scenario_file=scenario_file)
#       5 simple_network.get_disrupted_components()
#
# TypeError: IntegratedNetwork.set_disrupted_components() got an unexpected keyword argument 'scenario_file'

# %% [markdown]
# ### Set initial crew locations

# %%
simple_network.deploy_crews(
    init_power_crew_locs=['T_J8'], 
    init_water_crew_locs=['T_J8'],
    init_transpo_crew_locs= ['T_J8']
    )
# Out:
# Power repair crews successfully deployed.
# Water repair crews successfully deployed.
# Transportation repair crews successfully deployed.

# %% [markdown]
# ## Simulation of interdependent effects using a test scenario
# ### (a) Create NetworkRecovery and Optimizer objects

# %%
network_recovery = NetworkRecovery(simple_network, 
                                   sim_step=60, 
                                   pipe_close_policy="repair",
                                   pipe_closure_delay= 10, 
                                   line_close_policy="sensor_based_line_isolation",
                                   line_closure_delay= 10)
bf_optimizer = BruteForceOptimizer(prediction_horizon = 2)

# %% [markdown]
# ### (b) Create a simulation object

# %%
sim_step = (
    simple_network.wn.options.time.hydraulic_timestep
)  # initial_sim_step which will be updated during the simulation
bf_simulation = simulation.NetworkSimulation(network_recovery, sim_step)

# %% [markdown]
# ### (c) Optimization of repair strategy

# %%
bf_optimizer.find_optimal_recovery(bf_simulation)
# Out:
# PREDICTION HORIZON 1
# **************************************************
# Components to repair:  ['W_P21', 'W_WP9', 'T_L2', 'P_L5'] Components repaired:  []
# Repair orders under consideration in the current prediction horizon:  [['W_P21', 'W_WP9'], ['W_P21', 'T_L2'], ['W_P21', 'P_L5'], ['W_WP9', 'W_P21'], ['W_WP9', 'T_L2'], ['W_WP9', 'P_L5'], ['T_L2', 'W_P21'], ['T_L2', 'W_WP9'], ['T_L2', 'P_L5'], ['P_L5', 'W_P21'], ['P_L5', 'W_WP9'], ['P_L5', 'T_L2']]
# --------------------------------------------------
# Simulating the current cumulative repair order ['W_P21', 'W_WP9'] ...
# ['T_L19'] 4.0
# Repair W_P21: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 14 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21.
# ['T_L13', 'T_L15'] 9.0
# Repair W_WP9: The water crew 1 is at T_J5 at t = 474.0  minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# All restoration actions are successfully scheduled.
# [60, 6060, 6900, 28380, 28500, 28620, 29580, 33780, 33900, 34020, 64500, 69900]
# [6000, 840, 21480, 120, 120, 960, 4200, 120, 120, 30480, 5400]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6060 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 28380.0...
# ******************
#
# Simulating network conditions until 28380 s
# Simulation time:  28380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28380.0 and 28500.0...
# ******************
#
# Simulating network conditions until 28500 s
# Simulation time:  28500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28500.0 and 28620.0...
# ******************
#
# Simulating network conditions until 28620 s
# Simulation time:  28620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28620.0 and 29580.0...
# ******************
#
# Simulating network conditions until 29580 s
# Simulation time:  29580.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 29580.0 and 33780.0...
# ******************
#
# Simulating network conditions until 33780 s
# Simulation time:  33780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 33780.0 and 33900.0...
# ******************
#
# Simulating network conditions until 33900 s
# Simulation time:  33900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 33900.0 and 34020.0...
# ******************
#
# Simulating network conditions until 34020 s
# Simulation time:  34020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 34020.0 and 64500.0...
# ******************
#
# Simulating network conditions until 64500 s
# Simulation time:  64500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 64500.0 and 69900.0...
# ******************
#
# The power Resilience Metric value based on ECS is 4.267 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.63 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 11.893 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 11.893 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 8.08
# The weighted AUC value based on PCS is 6.261500000000001
# Water AUC:  11.893 	 Power AUC:  0.63 	 Weighted AUC:  6.262
# Simulating the current cumulative repair order ['W_P21', 'T_L2'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# ['T_L19'] 4.0
# Repair W_P21: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 14 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21.
# All restoration actions are successfully scheduled.
# [60, 6060, 6900, 7260, 28380, 28500, 28620, 28740, 28860, 28980, 64500, 64860]
# [6000, 840, 360, 21120, 120, 120, 120, 120, 120, 35520, 360]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6060 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7260.0...
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 28380.0...
# ******************
#
# Simulating network conditions until 28380 s
# Simulation time:  28380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28380.0 and 28500.0...
# ******************
#
# Simulating network conditions until 28500 s
# Simulation time:  28500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28500.0 and 28620.0...
# ******************
#
# Simulating network conditions until 28620 s
# Simulation time:  28620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28620.0 and 28740.0...
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 64500.0...
# ******************
#
# Simulating network conditions until 64500 s
# Simulation time:  64500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 64500.0 and 64860.0...
# ******************
#
# The power Resilience Metric value based on ECS is 4.267 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.63 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 11.893 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 11.893 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 8.08
# The weighted AUC value based on PCS is 6.261500000000001
# Water AUC:  11.893 	 Power AUC:  0.63 	 Weighted AUC:  6.262
# Simulating the current cumulative repair order ['W_P21', 'P_L5'] ...
# ['T_L19'] 4.0
# Repair W_P21: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 14 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21.
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 15780, 15900, 16020, 28380, 28500, 28620, 51900, 64500]
# [6000, 600, 240, 8880, 120, 120, 12360, 120, 120, 23280, 12600]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 15780.0...
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 28380.0...
# ******************
#
# Simulating network conditions until 28380 s
# Simulation time:  28380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28380.0 and 28500.0...
# ******************
#
# Simulating network conditions until 28500 s
# Simulation time:  28500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28500.0 and 28620.0...
# ******************
#
# Simulating network conditions until 28620 s
# Simulation time:  28620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28620.0 and 51900.0...
# ******************
#
# Simulating network conditions until 51900 s
# Simulation time:  51900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51900.0 and 64500.0...
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 8.393 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.393 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.6405
# The weighted AUC value based on PCS is 4.2620000000000005
# Water AUC:  8.393 	 Power AUC:  0.131 	 Weighted AUC:  4.262
# Simulating the current cumulative repair order ['W_WP9', 'W_P21'] ...
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# ['T_L4', 'T_L2'] 9.0
# Repair W_P21: The water crew 1 is at T_J2 at t = 195.0  minutes. It takes 19 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21.
# All restoration actions are successfully scheduled.
# [60, 6060, 7500, 11700, 11820, 11940, 12900, 34380, 34500, 34620, 47820, 70500]
# [6000, 1440, 4200, 120, 120, 960, 21480, 120, 120, 13200, 22680]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 7500.0...
# The pipe leak control for W_P21 is added between 6060 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 12900.0...
# The pipe leak control for W_P21 is added between 11940 s and 12900.0 s
# ******************
#
# Simulating network conditions until 12900 s
# Simulation time:  12900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 12900.0 and 34380.0...
# ******************
#
# Simulating network conditions until 34380 s
# Simulation time:  34380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 34380.0 and 34500.0...
# ******************
#
# Simulating network conditions until 34500 s
# Simulation time:  34500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 34500.0 and 34620.0...
# ******************
#
# Simulating network conditions until 34620 s
# Simulation time:  34620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 34620.0 and 47820.0...
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 70500.0...
# ******************
#
# The power Resilience Metric value based on ECS is 3.108 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.459 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 10.473 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 10.472 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 6.790500000000001
# The weighted AUC value based on PCS is 5.4655
# Water AUC:  10.472 	 Power AUC:  0.459 	 Weighted AUC:  5.466
# Simulating the current cumulative repair order ['W_WP9', 'T_L2'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# All restoration actions are successfully scheduled.
# [60, 6060, 7260, 7500, 11700, 11820, 11940, 28740, 28860, 28980, 47820, 64860]
# [6000, 1200, 240, 4200, 120, 120, 16800, 120, 120, 18840, 17040]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 7260.0...
# The pipe leak control for W_P21 is added between 6060 s and 7260.0 s
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 7500.0...
# The pipe leak control for W_P21 is added between 7260 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 28740.0...
# The pipe leak control for W_P21 is added between 11940 s and 28740.0 s
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# The pipe leak control for W_P21 is added between 28740 s and 28860.0 s
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# The pipe leak control for W_P21 is added between 28860 s and 28980.0 s
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 47820.0...
# The pipe leak control for W_P21 is added between 28980 s and 47820.0 s
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 64860.0...
# The pipe leak control for W_P21 is added between 47820 s and 64860.0 s
# ******************
#
# The power Resilience Metric value based on ECS is 3.108 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.459 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 10.473 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 10.472 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 6.790500000000001
# The weighted AUC value based on PCS is 5.4655
# Water AUC:  10.472 	 Power AUC:  0.459 	 Weighted AUC:  5.466
# Simulating the current cumulative repair order ['W_WP9', 'P_L5'] ...
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 7500, 11700, 11820, 11940, 15780, 15900, 16020, 47820, 51900]
# [6000, 600, 240, 600, 4200, 120, 120, 3840, 120, 120, 31800, 4080]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7500.0...
# The pipe leak control for W_P21 is added between 6900 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 15780.0...
# The pipe leak control for W_P21 is added between 11940 s and 15780.0 s
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# The pipe leak control for W_P21 is added between 15780 s and 15900.0 s
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# The pipe leak control for W_P21 is added between 15900 s and 16020.0 s
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 47820.0...
# The pipe leak control for W_P21 is added between 16020 s and 47820.0 s
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 51900.0...
# The pipe leak control for W_P21 is added between 47820 s and 51900.0 s
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.003 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 3.917 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 2.4455
# The weighted AUC value based on PCS is 2.024
# Water AUC:  3.917 	 Power AUC:  0.131 	 Weighted AUC:  2.024
# Simulating the current cumulative repair order ['T_L2', 'W_P21'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# ['T_L19'] 4.0
# Repair W_P21: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 14 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21.
# All restoration actions are successfully scheduled.
# [60, 6060, 6900, 7260, 28380, 28500, 28620, 28740, 28860, 28980, 64500, 64860]
# [6000, 840, 360, 21120, 120, 120, 120, 120, 120, 35520, 360]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6060 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7260.0...
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 28380.0...
# ******************
#
# Simulating network conditions until 28380 s
# Simulation time:  28380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28380.0 and 28500.0...
# ******************
#
# Simulating network conditions until 28500 s
# Simulation time:  28500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28500.0 and 28620.0...
# ******************
#
# Simulating network conditions until 28620 s
# Simulation time:  28620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28620.0 and 28740.0...
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 64500.0...
# ******************
#
# Simulating network conditions until 64500 s
# Simulation time:  64500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 64500.0 and 64860.0...
# ******************
#
# The power Resilience Metric value based on ECS is 4.267 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.63 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 11.893 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 11.893 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 8.08
# The weighted AUC value based on PCS is 6.261500000000001
# Water AUC:  11.893 	 Power AUC:  0.63 	 Weighted AUC:  6.262
# Simulating the current cumulative repair order ['T_L2', 'W_WP9'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# All restoration actions are successfully scheduled.
# [60, 6060, 7260, 7500, 11700, 11820, 11940, 28740, 28860, 28980, 47820, 64860]
# [6000, 1200, 240, 4200, 120, 120, 16800, 120, 120, 18840, 17040]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 7260.0...
# The pipe leak control for W_P21 is added between 6060 s and 7260.0 s
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 7500.0...
# The pipe leak control for W_P21 is added between 7260 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 28740.0...
# The pipe leak control for W_P21 is added between 11940 s and 28740.0 s
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# The pipe leak control for W_P21 is added between 28740 s and 28860.0 s
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# The pipe leak control for W_P21 is added between 28860 s and 28980.0 s
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 47820.0...
# The pipe leak control for W_P21 is added between 28980 s and 47820.0 s
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 64860.0...
# The pipe leak control for W_P21 is added between 47820 s and 64860.0 s
# ******************
#
# The power Resilience Metric value based on ECS is 3.108 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.459 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 10.473 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 10.472 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 6.790500000000001
# The weighted AUC value based on PCS is 5.4655
# Water AUC:  10.472 	 Power AUC:  0.459 	 Weighted AUC:  5.466
# Simulating the current cumulative repair order ['T_L2', 'P_L5'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 7260, 15780, 15900, 16020, 28740, 28860, 28980, 51900, 64860]
# [6000, 600, 240, 360, 8520, 120, 120, 12720, 120, 120, 22920, 12960]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7260.0...
# The pipe leak control for W_P21 is added between 6900 s and 7260.0 s
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 15780.0...
# The pipe leak control for W_P21 is added between 7260 s and 15780.0 s
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# The pipe leak control for W_P21 is added between 15780 s and 15900.0 s
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# The pipe leak control for W_P21 is added between 15900 s and 16020.0 s
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 28740.0...
# The pipe leak control for W_P21 is added between 16020 s and 28740.0 s
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# The pipe leak control for W_P21 is added between 28740 s and 28860.0 s
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# The pipe leak control for W_P21 is added between 28860 s and 28980.0 s
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 51900.0...
# The pipe leak control for W_P21 is added between 28980 s and 51900.0 s
# ******************
#
# Simulating network conditions until 51900 s
# Simulation time:  51900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51900.0 and 64860.0...
# The pipe leak control for W_P21 is added between 51900 s and 64860.0 s
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 11.607 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 11.605 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 6.2475
# The weighted AUC value based on PCS is 5.868
# Water AUC:  11.605 	 Power AUC:  0.131 	 Weighted AUC:  5.868
# Simulating the current cumulative repair order ['P_L5', 'W_P21'] ...
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# ['T_L19'] 4.0
# Repair W_P21: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 14 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 15780, 15900, 16020, 28380, 28500, 28620, 51900, 64500]
# [6000, 600, 240, 8880, 120, 120, 12360, 120, 120, 23280, 12600]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 15780.0...
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 28380.0...
# ******************
#
# Simulating network conditions until 28380 s
# Simulation time:  28380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28380.0 and 28500.0...
# ******************
#
# Simulating network conditions until 28500 s
# Simulation time:  28500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28500.0 and 28620.0...
# ******************
#
# Simulating network conditions until 28620 s
# Simulation time:  28620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28620.0 and 51900.0...
# ******************
#
# Simulating network conditions until 51900 s
# Simulation time:  51900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51900.0 and 64500.0...
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 8.393 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.393 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.6405
# The weighted AUC value based on PCS is 4.2620000000000005
# Water AUC:  8.393 	 Power AUC:  0.131 	 Weighted AUC:  4.262
# Simulating the current cumulative repair order ['P_L5', 'W_WP9'] ...
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 7500, 11700, 11820, 11940, 15780, 15900, 16020, 47820, 51900]
# [6000, 600, 240, 600, 4200, 120, 120, 3840, 120, 120, 31800, 4080]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7500.0...
# The pipe leak control for W_P21 is added between 6900 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 15780.0...
# The pipe leak control for W_P21 is added between 11940 s and 15780.0 s
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# The pipe leak control for W_P21 is added between 15780 s and 15900.0 s
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# The pipe leak control for W_P21 is added between 15900 s and 16020.0 s
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 47820.0...
# The pipe leak control for W_P21 is added between 16020 s and 47820.0 s
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 51900.0...
# The pipe leak control for W_P21 is added between 47820 s and 51900.0 s
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.003 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 3.917 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 2.4455
# The weighted AUC value based on PCS is 2.024
# Water AUC:  3.917 	 Power AUC:  0.131 	 Weighted AUC:  2.024
# Simulating the current cumulative repair order ['P_L5', 'T_L2'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 7260, 15780, 15900, 16020, 28740, 28860, 28980, 51900, 64860]
# [6000, 600, 240, 360, 8520, 120, 120, 12720, 120, 120, 22920, 12960]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7260.0...
# The pipe leak control for W_P21 is added between 6900 s and 7260.0 s
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 15780.0...
# The pipe leak control for W_P21 is added between 7260 s and 15780.0 s
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# The pipe leak control for W_P21 is added between 15780 s and 15900.0 s
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# The pipe leak control for W_P21 is added between 15900 s and 16020.0 s
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 28740.0...
# The pipe leak control for W_P21 is added between 16020 s and 28740.0 s
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# The pipe leak control for W_P21 is added between 28740 s and 28860.0 s
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# The pipe leak control for W_P21 is added between 28860 s and 28980.0 s
# ...
# Water AUC:  2.616 	 Power AUC:  0.131 	 Weighted AUC:  1.374
# Simulating the current cumulative repair order ['T_L2', 'W_WP9', 'P_L5', 'W_P21'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# ['T_L4', 'T_L2'] 9.0
# Repair W_P21: The water crew 1 is at T_J2 at t = 195.0  minutes. It takes 303.0 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21 considering time for road link repair.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 7260, 7500, 11700, 11820, 11940, 15780, 15900, 16020, 28740, 28860, 28980, 29940, 47820, 51420, 51540, 51660, 51900, 64860, 87540]
# [6000, 600, 240, 360, 240, 4200, 120, 120, 3840, 120, 120, 12720, 120, 120, 960, 17880, 3600, 120, 120, 240, 12960, 22680]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7260.0...
# The pipe leak control for W_P21 is added between 6900 s and 7260.0 s
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 7500.0...
# The pipe leak control for W_P21 is added between 7260 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 15780.0...
# The pipe leak control for W_P21 is added between 11940 s and 15780.0 s
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# The pipe leak control for W_P21 is added between 15780 s and 15900.0 s
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# The pipe leak control for W_P21 is added between 15900 s and 16020.0 s
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 28740.0...
# The pipe leak control for W_P21 is added between 16020 s and 28740.0 s
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# The pipe leak control for W_P21 is added between 28740 s and 28860.0 s
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# The pipe leak control for W_P21 is added between 28860 s and 28980.0 s
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 29940.0...
# The pipe leak control for W_P21 is added between 28980 s and 29940.0 s
# ******************
#
# Simulating network conditions until 29940 s
# Simulation time:  29940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 29940.0 and 47820.0...
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 51420.0...
# ******************
#
# Simulating network conditions until 51420 s
# Simulation time:  51420.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51420.0 and 51540.0...
# ******************
#
# Simulating network conditions until 51540 s
# Simulation time:  51540.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51540.0 and 51660.0...
# ******************
#
# Simulating network conditions until 51660 s
# Simulation time:  51660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51660.0 and 51900.0...
# ******************
#
# Simulating network conditions until 51900 s
# Simulation time:  51900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51900.0 and 64860.0...
# ******************
#
# Simulating network conditions until 64860 s
# Simulation time:  64860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 64860.0 and 87540.0...
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 2.655 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 2.616 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7714999999999999
# The weighted AUC value based on PCS is 1.3735
# Water AUC:  2.616 	 Power AUC:  0.131 	 Weighted AUC:  1.374
#
# P_L5 is identified as the next best repair action in the current prediction horizon. The repair order ['T_L2', 'W_WP9', 'P_L5', 'W_P21'] produced the highest AUC of 1.374
# --------------------------------------------------
# PREDICTION HORIZON 4
# **************************************************
# Components to repair:  ['W_P21'] Components repaired:  ['T_L2', 'W_WP9', 'P_L5']
# Repair orders under consideration in the current prediction horizon:  [['W_P21']]
# --------------------------------------------------
# Simulating the current cumulative repair order ['T_L2', 'W_WP9', 'P_L5', 'W_P21'] ...
# Repair T_L2: The transpo crew 1 is at T_J8 at t = 100.0 minutes. It takes 19 minutes to reach nearest node T_J2, the nearest transportation node from T_L2.
# ['T_L13', 'T_L15', 'T_L19'] 13.0
# Repair W_WP9: The water crew 1 is at T_J8 at t = 100.0  minutes. It takes 23 minutes to reach nearest node T_J2, the nearest transportation  node from W_WP9.
# Repair P_L5: The power crew 1 is at T_J8 at t = 100.0 minutes. It takes 14 minutes to reach nearest node T_J5,  the nearest transportation node from P_L5.
# ['T_L4', 'T_L2'] 9.0
# Repair W_P21: The water crew 1 is at T_J2 at t = 195.0  minutes. It takes 303.0 minutes to reach nearest node T_J5, the nearest transportation  node from W_P21 considering time for road link repair.
# All restoration actions are successfully scheduled.
# [60, 6060, 6660, 6900, 7260, 7500, 11700, 11820, 11940, 15780, 15900, 16020, 28740, 28860, 28980, 29940, 47820, 51420, 51540, 51660, 51900, 64860, 87540]
# [6000, 600, 240, 360, 240, 4200, 120, 120, 3840, 120, 120, 12720, 120, 120, 960, 17880, 3600, 120, 120, 240, 12960, 22680]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 6060.0...
# ******************
#
# Simulating network conditions until 6060 s
# Simulation time:  6060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6060.0 and 6660.0...
# The pipe leak control for W_P21 is added between 6060 s and 6660.0 s
# ******************
#
# Simulating network conditions until 6660 s
# Simulation time:  6660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6660.0 and 6900.0...
# The pipe leak control for W_P21 is added between 6660 s and 6900.0 s
# ******************
#
# Simulating network conditions until 6900 s
# Simulation time:  6900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 6900.0 and 7260.0...
# The pipe leak control for W_P21 is added between 6900 s and 7260.0 s
# ******************
#
# Simulating network conditions until 7260 s
# Simulation time:  7260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7260.0 and 7500.0...
# The pipe leak control for W_P21 is added between 7260 s and 7500.0 s
# ******************
#
# Simulating network conditions until 7500 s
# Simulation time:  7500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 7500.0 and 11700.0...
# The pipe leak control for W_P21 is added between 7500 s and 11700.0 s
# ******************
#
# Simulating network conditions until 11700 s
# Simulation time:  11700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11700.0 and 11820.0...
# The pipe leak control for W_P21 is added between 11700 s and 11820.0 s
# ******************
#
# Simulating network conditions until 11820 s
# Simulation time:  11820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11820.0 and 11940.0...
# The pipe leak control for W_P21 is added between 11820 s and 11940.0 s
# ******************
#
# Simulating network conditions until 11940 s
# Simulation time:  11940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 11940.0 and 15780.0...
# The pipe leak control for W_P21 is added between 11940 s and 15780.0 s
# ******************
#
# Simulating network conditions until 15780 s
# Simulation time:  15780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15780.0 and 15900.0...
# The pipe leak control for W_P21 is added between 15780 s and 15900.0 s
# ******************
#
# Simulating network conditions until 15900 s
# Simulation time:  15900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 15900.0 and 16020.0...
# The pipe leak control for W_P21 is added between 15900 s and 16020.0 s
# ******************
#
# Simulating network conditions until 16020 s
# Simulation time:  16020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 16020.0 and 28740.0...
# The pipe leak control for W_P21 is added between 16020 s and 28740.0 s
# ******************
#
# Simulating network conditions until 28740 s
# Simulation time:  28740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28740.0 and 28860.0...
# The pipe leak control for W_P21 is added between 28740 s and 28860.0 s
# ******************
#
# Simulating network conditions until 28860 s
# Simulation time:  28860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28860.0 and 28980.0...
# The pipe leak control for W_P21 is added between 28860 s and 28980.0 s
# ******************
#
# Simulating network conditions until 28980 s
# Simulation time:  28980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 28980.0 and 29940.0...
# The pipe leak control for W_P21 is added between 28980 s and 29940.0 s
# ******************
#
# Simulating network conditions until 29940 s
# Simulation time:  29940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 29940.0 and 47820.0...
# ******************
#
# Simulating network conditions until 47820 s
# Simulation time:  47820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 47820.0 and 51420.0...
# ******************
#
# Simulating network conditions until 51420 s
# Simulation time:  51420.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51420.0 and 51540.0...
# ******************
#
# Simulating network conditions until 51540 s
# Simulation time:  51540.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51540.0 and 51660.0...
# ******************
#
# Simulating network conditions until 51660 s
# Simulation time:  51660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51660.0 and 51900.0...
# ******************
#
# Simulating network conditions until 51900 s
# Simulation time:  51900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 51900.0 and 64860.0...
# ******************
#
# Simulating network conditions until 64860 s
# Simulation time:  64860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 64860.0 and 87540.0...
# ******************
#
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 2.655 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 2.616 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7714999999999999
# The weighted AUC value based on PCS is 1.3735
# Water AUC:  2.616 	 Power AUC:  0.131 	 Weighted AUC:  1.374
#
# W_P21 is identified as the next best repair action in the current prediction horizon. The repair order ['T_L2', 'W_WP9', 'P_L5', 'W_P21'] produced the highest AUC of 1.374
# --------------------------------------------------
# --------------------------------------------------
# Optimization completed. The MPC optimal repair order to restore the network is ['T_L2', 'W_WP9', 'P_L5', 'W_P21'].
# Process completed in  76.0  seconds

# %% [markdown]
# ### Plot the direct and interdependent effects

# %%
bf_optimizer.get_optimization_log()
# Out:
#                   repair_order  water_auc  power_auc    auc
# 0               [W_P21, W_WP9]     11.893      0.630  6.262
# 1                [W_P21, T_L2]     11.893      0.630  6.262
# 2                [W_P21, P_L5]      8.393      0.131  4.262
# 3               [W_WP9, W_P21]     10.472      0.459  5.466
# 4                [W_WP9, T_L2]     10.472      0.459  5.466
# 5                [W_WP9, P_L5]      3.917      0.131  2.024
# 6                [T_L2, W_P21]     11.893      0.630  6.262
# 7                [T_L2, W_WP9]     10.472      0.459  5.466
# 8                 [T_L2, P_L5]     11.605      0.131  5.868
# 9                [P_L5, W_P21]      8.393      0.131  4.262
# 10               [P_L5, W_WP9]      3.917      0.131  2.024
# 11                [P_L5, T_L2]     11.605      0.131  5.868
# 12        [T_L2, W_P21, W_WP9]     11.993      0.634  6.314
# 13         [T_L2, W_P21, P_L5]     11.893      0.131  6.012
# 14        [T_L2, W_WP9, W_P21]     15.205      0.634  7.920
# 15         [T_L2, W_WP9, P_L5]      4.213      0.131  2.172
# 16         [T_L2, P_L5, W_P21]     11.893      0.131  6.012
# 17         [T_L2, P_L5, W_WP9]      4.213      0.131  2.172
# 18  [T_L2, W_WP9, W_P21, P_L5]      2.616      0.131  1.374
# 19  [T_L2, W_WP9, P_L5, W_P21]      2.616      0.131  1.374
# 20  [T_L2, W_WP9, P_L5, W_P21]      2.616      0.131  1.374

# %%
bf_optimizer.best_repair_strategy
# Out:
# ['T_L2', 'W_WP9', 'P_L5', 'W_P21']

# %%
bf_optimizer.resilience_metrics.calculate_power_resmetric(network_recovery)
# Out:
# The power Resilience Metric value based on ECS is 0.888 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.131 equivalent outage hours (EOH)

# %%
bf_optimizer.resilience_metrics.calculate_water_resmetrics(network_recovery)
# Out:
# The water Resilience Metric value based on ECS is 2.655 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 2.616 equivalent outage hours (EOH)

# %%
bf_optimizer.resilience_metrics.set_weighted_auc_metrics()
# Out:
# The weighted AUC value based on ECS is 1.7714999999999999
# The weighted AUC value based on PCS is 1.3735

# %%
model_plots.plot_interdependent_effects(bf_optimizer.resilience_metrics, metric = 'pcs', title = False)
